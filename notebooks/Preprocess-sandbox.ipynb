# %% [markdown]
# ## Define Variables / Import MetaData

# %%
import sys
import os
from pathlib import Path

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import xarray as xr
from cartopy import crs as ccrs 
import datetime
import glob
import os

# %%
# Define misc variables
amer_filepath = '../../ameriflux-data/'
mic_filepath = '../../micasa-data/'
timedelta = 'DD'

# %%
# Import site metadata csv
meta_file = amer_filepath + 'AmeriFlux-site-search-results-202410071335.tsv'
ameriflux_meta = pd.read_csv(meta_file, sep='\t')
fluxnet_meta = ameriflux_meta.loc[ameriflux_meta['AmeriFlux FLUXNET Data'] == 'Yes'] #use FLUXNET only

# %%
fluxnet_meta
# Out:
#     Site ID                                               Name  \
# 5    AR-TF1                                       Rio Moat bog
# 9    BR-CST                             Caatinga Serra Talhada
# 18   BR-Npw                          Northern Pantanal Wetland
# 25   CA-ARB                             Attawapiskat River Bog
# 26   CA-ARF                             Attawapiskat River Fen
# ..      ...                                                ...
# 664  US-xTR                              NEON Treehaven (TREE)
# 665  US-xUK  NEON The University of Kansas Field Station (U...
# 666  US-xUN  NEON University of Notre Dame Environmental Re...
# 667  US-xWD                              NEON Woodworth (WOOD)
# 669  US-xYE  NEON Yellowstone Northern Range (Frog Rock) (Y...
#
#                                 Principal Investigator Data Use Policy  \
# 5    Veronica Pancotto (pancotto@cadic-conicet.gob.ar)       CC-BY-4.0
# 9             Antonio Antonino (acdantonino@gmail.com)       CC-BY-4.0
# 18                  Mark Johnson (mark.johnson@ubc.ca)       CC-BY-4.0
# 25    Elyn Humphreys (elynhumphreys@cunet.carleton.ca)       CC-BY-4.0
# 26    Elyn Humphreys (elynhumphreys@cunet.carleton.ca)       CC-BY-4.0
# ..                                                 ...             ...
# 664  National Ecological Observatory Network (neon-...       CC-BY-4.0
# 665  National Ecological Observatory Network (neon-...       CC-BY-4.0
# 666  National Ecological Observatory Network (neon-...       CC-BY-4.0
# 667  National Ecological Observatory Network (neon-...       CC-BY-4.0
# 669  National Ecological Observatory Network (neon-...       CC-BY-4.0
#
#     AmeriFlux BASE Data AmeriFlux FLUXNET Data Vegetation Abbreviation (IGBP)  \
# 5                   Yes                    Yes                            WET
# 9                   Yes                    Yes                            DNF
# 18                  Yes                    Yes                            WSA
# 25                  Yes                    Yes                            WET
# 26                  Yes                    Yes                            WET
# ..                  ...                    ...                            ...
# 664                 Yes                    Yes                            DBF
# 665                 Yes                    Yes                            DBF
# 666                 Yes                    Yes                             MF
# 667                 Yes                    Yes                            GRA
# 669                 Yes                    Yes                            ENF
#
#                          Vegetation Description (IGBP)  \
# 5    Permanent Wetlands: Lands with a permanent mix...
# 9    Deciduous Needleleaf Forests: Lands dominated ...
# 18   Woody Savannas: Lands with herbaceous and othe...
# 25   Permanent Wetlands: Lands with a permanent mix...
# 26   Permanent Wetlands: Lands with a permanent mix...
# ..                                                 ...
# 664  Deciduous Broadleaf Forests: Lands dominated b...
# 665  Deciduous Broadleaf Forests: Lands dominated b...
# 666  Mixed Forests: Lands dominated by trees with a...
# 667  Grasslands: Lands with herbaceous types of cov...
# 669  Evergreen Needleleaf Forests: Lands dominated ...
#
#     Climate Class Abbreviation (Koeppen)  \
# 5                                    NaN
# 9                                    Bsh
# 18                                    Aw
# 25                                   Dfb
# 26                                   Dfb
# ..                                   ...
# 664                                  Dfb
# 665                                  Cfa
# 666                                  Dfb
# 667                                  Dfb
# 669                                  Dfc
#
#                    Climate Class Description (Koeppen)  ...  \
# 5                                                  NaN  ...
# 9                             Steppe: very cold winter  ...
# 18                                    Tropical savanna  ...
# 25   Warm Summer Continental: significant precipita...  ...
# 26   Warm Summer Continental: significant precipita...  ...
# ..                                                 ...  ...
# 664  Warm Summer Continental: significant precipita...  ...
# 665  Humid Subtropical: mild with no dry season, ho...  ...
# 666  Warm Summer Continental: significant precipita...  ...
# 667  Warm Summer Continental: significant precipita...  ...
# 669  Subarctic: severe winter, no dry season, cool ...  ...
#
#      Longitude (degrees)  Elevation (m)  \
# 5               -66.7335           40.0
# 9               -38.3842          468.0
# 18              -56.4120          120.0
# 25              -83.9452           90.0
# 26              -83.9550           88.0
# ..                   ...            ...
# 664             -89.5857          472.0
# 665             -95.1921          335.0
# 666             -89.5373          518.0
# 667             -99.2414          579.0
# 669            -110.5391         2116.0
#
#                  Years of AmeriFlux BASE Data  \
# 5                            2016, 2017, 2018
# 9                                  2014, 2015
# 18               2013, 2014, 2015, 2016, 2017
# 25               2011, 2012, 2013, 2014, 2015
# 26               2011, 2012, 2013, 2014, 2015
# ..                                        ...
# 664  2017, 2018, 2019, 2020, 2021, 2022, 2023
# 665  2017, 2018, 2019, 2020, 2021, 2022, 2023
# 666  2017, 2018, 2019, 2020, 2021, 2022, 2023
# 667  2017, 2018, 2019, 2020, 2021, 2022, 2023
# 669        2018, 2019, 2020, 2021, 2022, 2023
#
#                        AmeriFlux BASE DOI  Years of AmeriFlux FLUXNET Data  \
# 5    https://doi.org/10.17190/AMF/1543389                 2016, 2017, 2018
# 9    https://doi.org/10.17190/AMF/1562386                       2014, 2015
# 18   https://doi.org/10.17190/AMF/1579716     2013, 2014, 2015, 2016, 2017
# 25   https://doi.org/10.17190/AMF/1480319     2011, 2012, 2013, 2014, 2015
# 26   https://doi.org/10.17190/AMF/1480318     2011, 2012, 2013, 2014, 2015
# ..                                    ...                              ...
# 664  https://doi.org/10.17190/AMF/1634886     2017, 2018, 2019, 2020, 2021
# 665  https://doi.org/10.17190/AMF/1617740     2017, 2018, 2019, 2020, 2021
# 666  https://doi.org/10.17190/AMF/1617741     2017, 2018, 2019, 2020, 2021
# 667  https://doi.org/10.17190/AMF/1579724                 2019, 2020, 2021
# 669  https://doi.org/10.17190/AMF/1617743           2018, 2019, 2020, 2021
#
#                     AmeriFlux FLUXNET DOI Site Start Site End  \
# 5    https://doi.org/10.17190/AMF/1818370     2016.0   2018.0
# 9    https://doi.org/10.17190/AMF/1902820     2014.0      NaN
# 18   https://doi.org/10.17190/AMF/1881563     2013.0      NaN
# 25   https://doi.org/10.17190/AMF/1902821     2010.0      NaN
# 26   https://doi.org/10.17190/AMF/1902822     2010.0      NaN
# ..                                    ...        ...      ...
# 664  https://doi.org/10.17190/AMF/1985456     2017.0      NaN
# 665  https://doi.org/10.17190/AMF/1985457     2017.0      NaN
# 666  https://doi.org/10.17190/AMF/1985458     2017.0      NaN
# 667  https://doi.org/10.17190/AMF/2229412     2017.0      NaN
# 669  https://doi.org/10.17190/AMF/1985459     2018.0      NaN
#
#                               BASE variables available  \
# 5    CO2, FC, FC_SSITC_TEST, H, H_SSITC_TEST, LE, L...
# 9    APAR, CO2, FC, FETCH_90, GPP, H, H2O, H_SSITC_...
# 18   CH4, CO2, FC, FCH4, G, H, LE, LW_IN, LW_OUT, N...
# 25   ALB, CO2, D_SNOW, FC, G, H, LE, LW_IN, LW_OUT,...
# 26   ALB, CO2, D_SNOW, FC, G, H, LE, LW_IN, LW_OUT,...
# ..                                                 ...
# 664  CH4, CH4_MIXING_RATIO, CO2, CO2C13, CO2_MIXING...
# 665  CH4, CH4_MIXING_RATIO, CO2, CO2C13, CO2_MIXING...
# 666  CH4, CH4_MIXING_RATIO, CO2, CO2C13, CO2_MIXING...
# 667  CH4, CH4_MIXING_RATIO, CO2, CO2C13, CO2_MIXING...
# 669  CH4, CH4_MIXING_RATIO, CO2, CO2C13, CO2_MIXING...
#
#     FLUXNET variables available
# 5                           NaN
# 9                           NaN
# 18                          NaN
# 25                          NaN
# 26                          NaN
# ..                          ...
# 664                         NaN
# 665                         NaN
# 666                         NaN
# 667                         NaN
# 669                         NaN
#
# [196 rows x 24 columns]

# %%
total_sites = fluxnet_meta['Site ID'].to_list()
len(total_sites)

# %%
# set map proj
proj=ccrs.PlateCarree()

# %%
def get_single_match(pattern):
    matches = glob.glob(pattern)
    if len(matches) == 1:
        return matches[0]
    elif len(matches) == 0:
        raise ValueError(f"No matches found")
    else:
        raise ValueError(f"Multiple matches found: {matches}")

# %%
def get_amer_match(amer_filepath, site_ID):
    match = get_single_match(amer_filepath + 'AMF_' + site_ID +
                            '_FLUXNET_SUBSET_*/AMF_' + site_ID +
                            '_FLUXNET_SUBSET_' + timedelta + '*.csv')
    return match

# %% [markdown]
# ## B. Develop script to dump all variables requested into one preprocessed file

# %%
site_ID = 'AR-TF1'
# Define micasa variables wanted
micasa_var_list = ['NEE', 'NPP']
# Extract site lat/lon
site_lat = ameriflux_meta.loc[ameriflux_meta['Site ID'] == site_ID, 'Latitude (degrees)'].values
site_lon = ameriflux_meta.loc[ameriflux_meta['Site ID'] == site_ID, 'Longitude (degrees)'].values

# %%
# Import fluxnet 
fluxnet_sel = pd.read_csv(get_amer_match(amer_filepath, site_ID))

# %%
fluxnet_sel_dates = fluxnet_sel.loc[:,['TIMESTAMP']].copy()
fluxnet_sel_dates['TIMESTAMP'] = pd.to_datetime(fluxnet_sel_dates['TIMESTAMP'],format='%Y%m%d')
fluxnet_sel_dates = fluxnet_sel_dates.set_index('TIMESTAMP')
time = fluxnet_sel_dates.index
dates_unique = list({dt.date() for dt in time})
dates_unique.sort()
dates_unique[:5]

# %%
# Import micasa
# Test some random files
path_test_mon = glob.glob(mic_filepath + 'daily/2016/01/MiCASA_v1_flux_x3600_y1800_daily_201601*.nc4')
path_sorted_mon = sorted(path_test_mon)

path_test_yr = glob.glob(mic_filepath + 'daily/2016/??/MiCASA_v1_flux_x3600_y1800_daily_20??????.nc4')
path_sorted_yr = sorted(path_test_yr)

path_test_all = glob.glob(mic_filepath + 'daily/20??/??/MiCASA_v1_flux_x3600_y1800_daily_20??????.nc4')
path_sorted_all = sorted(path_test_all)

# %%
print(path_sorted_mon[0], len(path_sorted_mon), len(path_sorted_yr), len(path_sorted_all), sep=',  ')

# %%
# %%time
# ds = xr.open_mfdataset(path_test_mon)
# ds = xr.open_mfdataset(path_sorted_mon)[micasa_var_list] 
ds = xr.open_mfdataset(path_sorted_mon, 
                       engine = 'h5netcdf',
                       # combine='nested', concat_dim='time',
                      )[micasa_var_list]
# ds = xr.open_mfdataset(path_sorted_mon, parallel=True)[micasa_var_list] #Test this when I can get the dashboard to work
ds

# Note: 
# Not clear how fast combine=nested, concat_dim='time' improves speed over default combine='by-coords'
# Adding in just relevant variables seems to shorten time several seconds for 1 month

# %%
# IMO this is all slow and i should virtualize... because then I can reuse the virtualized store for across all sites, since there are year crossovers?
# Or perhaps I should load all the micasa data at once and subset from there? That would avoid opening some files multiple times
# How long does it take to open the micasa data? ~10 seconds for 1 month, 1:30 for 1 year, too long to run all

# %%
# %%time
ds_subset = ds.sel(lon=site_lon, lat=site_lat, method='nearest')
ds_subset

# %%
# ds_out = pd.DataFrame()
# with xr.open_mfdataset(path_test_mon)[micasa_var_list] as ds:
#     # Select grid closest to selected site
#     ds_subset = ds.sel(lon=site_lon, lat=site_lat, method='nearest')
#     # print(ds_subset)
    
#     # Prep data for writing to csv
#     ds_subset = ds_subset.squeeze(dim=['lat','lon'],drop=True)
#     # print(ds_subset)
    
#     # Output a single file for each site with all variables
#     for micasa_var in micasa_var_list:
#         ds_out[micasa_var] = ds_subset[micasa_var].to_dataframe()
#         ds_out.rename(columns={micasa_var: f'MiCASA {micasa_var} ({ds_subset[micasa_var].units})'}, inplace=True)
